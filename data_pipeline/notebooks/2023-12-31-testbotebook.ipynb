# %%
import awswrangler as wr
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # need to reauthenticate this every day

# %%
df = wr.s3.read_csv("s3://de-sales-data-project-raw-data-146479615822/Online_Shopping_Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           52955 non-null  int64
#  1   CustomerID           52924 non-null  float64
#  2   Gender               52924 non-null  object
#  3   Location             52924 non-null  object
#  4   Tenure_Months        52924 non-null  float64
#  5   Transaction_ID       52924 non-null  float64
#  6   Transaction_Date     52924 non-null  object
#  7   Product_SKU          52924 non-null  object
#  8   Product_Description  52924 non-null  object
#  9   Product_Category     52955 non-null  object
#  10  Quantity             52924 non-null  float64
#  11  Avg_Price            52924 non-null  float64
#  12  Delivery_Charges     52924 non-null  float64
#  13  Coupon_Status        52924 non-null  object
#  14  GST                  52924 non-null  float64
#  15  Date                 52924 non-null  object
#  16  Offline_Spend        52924 non-null  float64
#  17  Online_Spend         52924 non-null  float64
#  18  Month                52955 non-null  int64
#  19  Coupon_Code          52555 non-null  object
#  20  Discount_pct         52555 non-null  float64
# dtypes: float64(10), int64(2), object(9)
# memory usage: 8.5+ MB

# %%
df
# Out:
#        Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0               0     17850.0      M  Chicago           12.0         16679.0
# 1               1     17850.0      M  Chicago           12.0         16680.0
# 2               2     17850.0      M  Chicago           12.0         16696.0
# 3               3     17850.0      M  Chicago           12.0         16699.0
# 4               4     17850.0      M  Chicago           12.0         16700.0
# ...           ...         ...    ...      ...            ...             ...
# 52950       52950         NaN    NaN      NaN            NaN             NaN
# 52951       52951         NaN    NaN      NaN            NaN             NaN
# 52952       52952         NaN    NaN      NaN            NaN             NaN
# 52953       52953         NaN    NaN      NaN            NaN             NaN
# 52954       52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# 0           2019-01-01  GGOENEBJ079499
# 1           2019-01-01  GGOENEBJ079499
# 2           2019-01-01  GGOENEBQ078999
# 3           2019-01-01  GGOENEBQ079099
# 4           2019-01-01  GGOENEBJ079499
# ...                ...             ...
# 52950              NaN             NaN
# 52951              NaN             NaN
# 52952              NaN             NaN
# 52953              NaN             NaN
# 52954              NaN             NaN
#
#                                      Product_Description  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2                 Nest Cam Outdoor Security Camera - USA
# 3        Nest Protect Smoke + CO White Battery Alarm-USA
# 4      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# ...                                                  ...
# 52950                                                NaN
# 52951                                                NaN
# 52952                                                NaN
# 52953                                                NaN
# 52954                                                NaN
#
#            Product_Category  Quantity  Avg_Price  Delivery_Charges  \
# 0                  Nest-USA       1.0     153.71               6.5
# 1                  Nest-USA       1.0     153.71               6.5
# 2                  Nest-USA       2.0     122.77               6.5
# 3                  Nest-USA       1.0      81.50               6.5
# 4                  Nest-USA       1.0     153.71               6.5
# ...                     ...       ...        ...               ...
# 52950            Gift Cards       NaN        NaN               NaN
# 52951  Notebooks & Journals       NaN        NaN               NaN
# 52952               Android       NaN        NaN               NaN
# 52953               Android       NaN        NaN               NaN
# 52954               Android       NaN        NaN               NaN
#
#       Coupon_Status  GST      Date  Offline_Spend  Online_Spend  Month  \
# 0              Used  0.1  1/1/2019         4500.0        2424.5      1
# 1              Used  0.1  1/1/2019         4500.0        2424.5      1
# 2          Not Used  0.1  1/1/2019         4500.0        2424.5      1
# 3           Clicked  0.1  1/1/2019         4500.0        2424.5      1
# 4           Clicked  0.1  1/1/2019         4500.0        2424.5      1
# ...             ...  ...       ...            ...           ...    ...
# 52950           NaN  NaN       NaN            NaN           NaN     11
# 52951           NaN  NaN       NaN            NaN           NaN     11
# 52952           NaN  NaN       NaN            NaN           NaN     10
# 52953           NaN  NaN       NaN            NaN           NaN     11
# 52954           NaN  NaN       NaN            NaN           NaN     12
#
#       Coupon_Code  Discount_pct
# 0          ELEC10          10.0
# 1          ELEC10          10.0
# 2          ELEC10          10.0
# 3          ELEC10          10.0
# 4          ELEC10          10.0
# ...           ...           ...
# 52950        GC20          20.0
# 52951        NJ20          20.0
# 52952       AND10          10.0
# 52953       AND20          20.0
# 52954       AND30          30.0
#
# [52955 rows x 21 columns]

# %%
df.head(30)
# Out:
#     Unnamed: 0  CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 0            0     17850.0      M     Chicago           12.0         16679.0
# 1            1     17850.0      M     Chicago           12.0         16680.0
# 2            2     17850.0      M     Chicago           12.0         16696.0
# 3            3     17850.0      M     Chicago           12.0         16699.0
# 4            4     17850.0      M     Chicago           12.0         16700.0
# 5            5     17850.0      M     Chicago           12.0         16701.0
# 6            6     17850.0      M     Chicago           12.0         16702.0
# 7            7     17850.0      M     Chicago           12.0         16703.0
# 8            8     17850.0      M     Chicago           12.0         16704.0
# 9            9     17850.0      M     Chicago           12.0         16710.0
# 10          10     17850.0      M     Chicago           12.0         16713.0
# 11          11     17850.0      M     Chicago           12.0         16719.0
# 12          12     17850.0      M     Chicago           12.0         16720.0
# 13          13     17850.0      M     Chicago           12.0         16720.0
# 14          14     17850.0      M     Chicago           12.0         16721.0
# 15          15     17850.0      M     Chicago           12.0         16722.0
# 16          16     17850.0      M     Chicago           12.0         16722.0
# 17          17     17850.0      M     Chicago           12.0         16723.0
# 18          18     17850.0      M     Chicago           12.0         16723.0
# 19          19     17850.0      M     Chicago           12.0         16724.0
# 20          20     17850.0      M     Chicago           12.0         16725.0
# 21          21     17850.0      M     Chicago           12.0         16727.0
# 22          22     17850.0      M     Chicago           12.0         16731.0
# 23          23     13047.0      M  California           43.0         16684.0
# 24          24     13047.0      M  California           43.0         16684.0
# 25          25     13047.0      M  California           43.0         16688.0
# 26          26     13047.0      M  California           43.0         16689.0
# 27          27     12583.0      M     Chicago           33.0         16694.0
# 28          28     15100.0      M  California           49.0         16712.0
# 29          29     14688.0      F    New York           46.0         16732.0
#
#    Transaction_Date     Product_SKU  \
# 0        2019-01-01  GGOENEBJ079499
# 1        2019-01-01  GGOENEBJ079499
# 2        2019-01-01  GGOENEBQ078999
# 3        2019-01-01  GGOENEBQ079099
# 4        2019-01-01  GGOENEBJ079499
# 5        2019-01-01  GGOENEBJ079499
# 6        2019-01-01  GGOENEBJ079499
# 7        2019-01-01  GGOENEBQ079099
# 8        2019-01-01  GGOENEBJ079499
# 9        2019-01-01  GGOENEBJ079499
# 10       2019-01-01  GGOENEBQ078999
# 11       2019-01-01  GGOENEBJ079499
# 12       2019-01-01  GGOENEBJ079499
# 13       2019-01-01  GGOENEBQ078999
# 14       2019-01-01  GGOENEBJ079499
# 15       2019-01-01  GGOENEBJ079499
# 16       2019-01-01  GGOENEBQ078999
# 17       2019-01-01  GGOENEBB078899
# 18       2019-01-01  GGOENEBQ078999
# 19       2019-01-01  GGOENEBB078899
# 20       2019-01-01  GGOENEBB078899
# 21       2019-01-01  GGOENEBB078899
# 22       2019-01-01  GGOENEBQ078999
# 23       2019-01-01  GGOENEBQ078999
# 24       2019-01-01  GGOENEBQ079199
# 25       2019-01-01  GGOENEBB078899
# 26       2019-01-01  GGOENEBJ079499
# 27       2019-01-01  GGOENEBB078899
# 28       2019-01-01  GGOENEBJ079499
# 29       2019-01-01  GGOENEBJ079499
#
#                                   Product_Description Product_Category  \
# 0   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Nest Cam Outdoor Security Camera - USA         Nest-USA
# 3     Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 4   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 5   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 6   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 7     Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 8   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 9   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 10             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 11  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 12  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 13             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 14  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 15  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 16             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 17              Nest Cam Indoor Security Camera - USA         Nest-USA
# 18             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 19              Nest Cam Indoor Security Camera - USA         Nest-USA
# 20              Nest Cam Indoor Security Camera - USA         Nest-USA
# 21              Nest Cam Indoor Security Camera - USA         Nest-USA
# 22             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 23             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 24      Nest Protect Smoke + CO White Wired Alarm-USA         Nest-USA
# 25              Nest Cam Indoor Security Camera - USA         Nest-USA
# 26  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 27              Nest Cam Indoor Security Camera - USA         Nest-USA
# 28  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 29  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
#
#     Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST      Date  \
# 0        1.0     153.71              6.50          Used  0.1  1/1/2019
# 1        1.0     153.71              6.50          Used  0.1  1/1/2019
# 2        2.0     122.77              6.50      Not Used  0.1  1/1/2019
# 3        1.0      81.50              6.50       Clicked  0.1  1/1/2019
# 4        1.0     153.71              6.50       Clicked  0.1  1/1/2019
# 5        1.0     153.71              6.50       Clicked  0.1  1/1/2019
# 6        2.0     153.71              6.50       Clicked  0.1  1/1/2019
# 7        2.0      81.50              6.50      Not Used  0.1  1/1/2019
# 8        1.0     256.88              6.50          Used  0.1  1/1/2019
# 9        1.0     153.71             28.78       Clicked  0.1  1/1/2019
# 10       1.0     122.77              6.50          Used  0.1  1/1/2019
# 11       1.0     153.71              6.50      Not Used  0.1  1/1/2019
# 12       1.0     153.71              6.50          Used  0.1  1/1/2019
# 13       1.0     122.77              6.50       Clicked  0.1  1/1/2019
# 14       1.0     153.71              6.50       Clicked  0.1  1/1/2019
# 15       1.0     153.71              6.50          Used  0.1  1/1/2019
# 16       2.0     122.77              6.50          Used  0.1  1/1/2019
# 17       1.0     122.77              6.50          Used  0.1  1/1/2019
# 18       1.0     122.77              6.50      Not Used  0.1  1/1/2019
# 19       1.0     122.77              6.50       Clicked  0.1  1/1/2019
# 20       1.0     122.77              6.50       Clicked  0.1  1/1/2019
# 21       1.0     122.77              6.50       Clicked  0.1  1/1/2019
# 22       2.0     122.77              6.50       Clicked  0.1  1/1/2019
# 23       2.0     122.77              6.50       Clicked  0.1  1/1/2019
# 24       1.0      81.50              6.50          Used  0.1  1/1/2019
# 25       1.0     122.77              6.50          Used  0.1  1/1/2019
# 26       1.0     153.71              6.50          Used  0.1  1/1/2019
# 27       1.0     122.77              6.50      Not Used  0.1  1/1/2019
# 28       1.0     153.71              6.50       Clicked  0.1  1/1/2019
# 29       1.0     153.71              6.50       Clicked  0.1  1/1/2019
#
#     Offline_Spend  Online_Spend  Month Coupon_Code  Discount_pct
# 0          4500.0        2424.5      1      ELEC10          10.0
# 1          4500.0        2424.5      1      ELEC10          10.0
# 2          4500.0        2424.5      1      ELEC10          10.0
# 3          4500.0        2424.5      1      ELEC10          10.0
# 4          4500.0        2424.5      1      ELEC10          10.0
# 5          4500.0        2424.5      1      ELEC10          10.0
# 6          4500.0        2424.5      1      ELEC10          10.0
# 7          4500.0        2424.5      1      ELEC10          10.0
# 8          4500.0        2424.5      1      ELEC10          10.0
# 9          4500.0        2424.5      1      ELEC10          10.0
# 10         4500.0        2424.5      1      ELEC10          10.0
# 11         4500.0        2424.5      1      ELEC10          10.0
# 12         4500.0        2424.5      1      ELEC10          10.0
# 13         4500.0        2424.5      1      ELEC10          10.0
# 14         4500.0        2424.5      1      ELEC10          10.0
# 15         4500.0        2424.5      1      ELEC10          10.0
# 16         4500.0        2424.5      1      ELEC10          10.0
# 17         4500.0        2424.5      1      ELEC10          10.0
# 18         4500.0        2424.5      1      ELEC10          10.0
# 19         4500.0        2424.5      1      ELEC10          10.0
# 20         4500.0        2424.5      1      ELEC10          10.0
# 21         4500.0        2424.5      1      ELEC10          10.0
# 22         4500.0        2424.5      1      ELEC10          10.0
# 23         4500.0        2424.5      1      ELEC10          10.0
# 24         4500.0        2424.5      1      ELEC10          10.0
# 25         4500.0        2424.5      1      ELEC10          10.0
# 26         4500.0        2424.5      1      ELEC10          10.0
# 27         4500.0        2424.5      1      ELEC10          10.0
# 28         4500.0        2424.5      1      ELEC10          10.0
# 29         4500.0        2424.5      1      ELEC10          10.0

# %% [markdown]
# ## Drop Missing:

# %%
def drop_na(df):
    clean_data = df.dropna()
    return clean_data
df = drop_na(df)
df
# Out:
#        Unnamed: 0  CustomerID Gender    Location  Tenure_Months  \
# 0               0     17850.0      M     Chicago           12.0
# 1               1     17850.0      M     Chicago           12.0
# 2               2     17850.0      M     Chicago           12.0
# 3               3     17850.0      M     Chicago           12.0
# 4               4     17850.0      M     Chicago           12.0
# ...           ...         ...    ...         ...            ...
# 52919       52919     13155.0      F  California            8.0
# 52920       52920     18077.0      M     Chicago           34.0
# 52921       52921     16085.0      M  California           15.0
# 52922       52922     16085.0      M  California           15.0
# 52923       52923     13659.0      F     Chicago            8.0
#
#        Transaction_ID Transaction_Date     Product_SKU  \
# 0             16679.0       2019-01-01  GGOENEBJ079499
# 1             16680.0       2019-01-01  GGOENEBJ079499
# 2             16696.0       2019-01-01  GGOENEBQ078999
# 3             16699.0       2019-01-01  GGOENEBQ079099
# 4             16700.0       2019-01-01  GGOENEBJ079499
# ...               ...              ...             ...
# 52919         22504.0       2019-03-10  GGOEGGCX056399
# 52920         24250.0       2019-03-28  GGOEGGCX056299
# 52921         39991.0       2019-10-06  GGOEGOCD078399
# 52922         39991.0       2019-10-06  GGOEGOCR078499
# 52923         39998.0       2019-10-06  GGOEGOCC077999
#
#                                      Product_Description  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2                 Nest Cam Outdoor Security Camera - USA
# 3        Nest Protect Smoke + CO White Battery Alarm-USA
# 4      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# ...                                                  ...
# 52919                                Gift Card - $250.00
# 52920                                 Gift Card - $25.00
# 52921                  Google Leather Perforated Journal
# 52922                      Google Spiral Leather Journal
# 52923                     Google Spiral Journal with Pen
#
#            Product_Category  Quantity  Avg_Price  Delivery_Charges  \
# 0                  Nest-USA       1.0     153.71               6.5
# 1                  Nest-USA       1.0     153.71               6.5
# 2                  Nest-USA       2.0     122.77               6.5
# 3                  Nest-USA       1.0      81.50               6.5
# 4                  Nest-USA       1.0     153.71               6.5
# ...                     ...       ...        ...               ...
# 52919            Gift Cards       1.0     250.00               0.0
# 52920            Gift Cards       1.0      25.00               0.0
# 52921  Notebooks & Journals       1.0      10.80               6.0
# 52922  Notebooks & Journals       1.0       9.60               6.0
# 52923  Notebooks & Journals       1.0       5.59               6.5
#
#       Coupon_Status   GST       Date  Offline_Spend  Online_Spend  Month  \
# 0              Used  0.10   1/1/2019         4500.0       2424.50      1
# 1              Used  0.10   1/1/2019         4500.0       2424.50      1
# 2          Not Used  0.10   1/1/2019         4500.0       2424.50      1
# 3           Clicked  0.10   1/1/2019         4500.0       2424.50      1
# 4           Clicked  0.10   1/1/2019         4500.0       2424.50      1
# ...             ...   ...        ...            ...           ...    ...
# 52919       Clicked  0.05  3/10/2019         2500.0       1294.22      3
# 52920          Used  0.05  3/28/2019         2000.0       1066.12      3
# 52921       Clicked  0.05  10/6/2019         3000.0       2230.76     10
# 52922          Used  0.05  10/6/2019         3000.0       2230.76     10
# 52923      Not Used  0.05  10/6/2019         3000.0       2230.76     10
#
#       Coupon_Code  Discount_pct
# 0          ELEC10          10.0
# 1          ELEC10          10.0
# 2          ELEC10          10.0
# 3          ELEC10          10.0
# 4          ELEC10          10.0
# ...           ...           ...
# 52919        GC30          30.0
# 52920        GC30          30.0
# 52921        NJ10          10.0
# 52922        NJ10          10.0
# 52923        NJ10          10.0
#
# [52524 rows x 21 columns]

# %% [markdown]
# # Rename Avg Price to Price

# %%
def rename_avg_price_to_price(df):
    # Rename 'Avg_Price' column to 'Price'
    df_renamed = df.rename(columns={'Avg_Price': 'Price'})
    return df_renamed
df = rename_avg_price_to_price(df)

# %%
df = df.drop(columns=['Unnamed: 0', 'Date'])

# %%
#df = df_new

# %%
df.sample(30)
# Out:
#        CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 31279     16891.0      M     Chicago           12.0         19508.0
# 6674      17337.0      F  California           44.0         46896.0
# 45828     14680.0      F  California           37.0         33877.0
# 32487     15570.0      F  New Jersey           34.0         20884.0
# 27279     15159.0      F     Chicago           29.0         43794.0
# 42901     14505.0      F  California            8.0         34157.0
# 11104     12766.0      F     Chicago           22.0         35413.0
# 30225     13709.0      F    New York           22.0         44057.0
# 20143     17033.0      M  California           47.0         29828.0
# 27379     12764.0      F     Chicago           25.0         42713.0
# 18743     17857.0      M     Chicago           47.0         30847.0
# 12081     12484.0      M  California           44.0         34689.0
# 50939     14130.0      F    New York           50.0         40951.0
# 47420     15464.0      F     Chicago           40.0         33668.0
# 35684     13455.0      F    New York           38.0         24844.0
# 1659      17732.0      F     Chicago            8.0         18066.0
# 5038      16745.0      F    New York           29.0         45852.0
# 44180     17634.0      F     Chicago           32.0         33951.0
# 51758     12474.0      F    New York           17.0         42258.0
# 5122      12502.0      F  California           23.0         47108.0
# 21586     13627.0      F     Chicago           49.0         31192.0
# 28396     12826.0      M  California           33.0         42912.0
# 15956     16081.0      M    New York           14.0         24406.0
# 14186     12490.0      F    New York           26.0         36992.0
# 2023      16274.0      F  California           43.0         17801.0
# 44077     17343.0      M    New York           32.0         31855.0
# 30658     12591.0      F  California           25.0         42411.0
# 38626     15808.0      F  California            6.0         28450.0
# 20504     17189.0      F    New York           42.0         30237.0
# 13854     14755.0      F  New Jersey           50.0         35224.0
#
#       Transaction_Date     Product_SKU  \
# 31279       2019-02-02  GGOENEBQ078999
# 6674        2019-12-14  GGOEGAET090515
# 45828       2019-07-27  GGOEGAWR061049
# 32487       2019-02-20  GGOEYAEJ029015
# 27279       2019-11-18  GGOENEBQ079099
# 42901       2019-07-31  GGOENEBQ078999
# 11104       2019-08-11  GGOEGAEJ028114
# 30225       2019-11-21  GGOENEBQ086799
# 20143       2019-06-07  GGOEGAEC029116
# 27379       2019-11-06  GGOENEBB078899
# 18743       2019-06-20  GGOENEBQ078999
# 12081       2019-08-04  GGOEGALB036513
# 50939       2019-10-17  GGOEGDHC074099
# 47420       2019-07-25  GGOEGPJC019099
# 35684       2019-04-05  GGOEGADB056915
# 1659        2019-01-17  GGOEGOAB021699
# 5038        2019-12-06  GGOENEBQ079099
# 44180       2019-07-28  GGOEGOCR017899
# 51758       2019-10-31  GGOENEBQ086799
# 5122        2019-12-16  GGOENEBB078899
# 21586       2019-06-25  GGOEGAAB010516
# 28396       2019-11-08  GGOEGOLC014299
# 15956       2019-03-29  GGOEGFKQ020399
# 14186       2019-08-30  GGOEGHPJ080310
# 2023        2019-01-13  GGOEGOAA017199
# 44077       2019-07-05  GGOEGOAC021799
# 30658       2019-11-02  GGOENEBQ092299
# 38626       2019-05-19  GGOENEBQ078999
# 20504       2019-06-12  GGOEGAAB033814
# 13854       2019-08-10  GGOEGPXC023299
#
#                                      Product_Description Product_Category  \
# 31279             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 6674                                   Google Tee Yellow          Apparel
# 45828                         Google Onesie Red/Graphite          Apparel
# 32487     YouTube Women's Short Sleeve Hero Tee Charcoal          Apparel
# 27279    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 42901             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 11104         Google Women's Short Sleeve Badge Tee Grey          Apparel
# 30225                            Nest Thermostat E - USA             Nest
# 20143      Google Women's Short Sleeve Hero Tee Sky Blue          Apparel
# 27379              Nest Cam Indoor Security Camera - USA         Nest-USA
# 18743             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 12081                Google Women's Scoop Neck Tee Black          Apparel
# 50939           Google 17oz Stainless Steel Sport Bottle        Drinkware
# 47420                                7&quot; Dog Frisbee        Lifestyle
# 35684     Google Men's Performance Full Zip Jacket Black          Apparel
# 1659                          Google Ballpoint Pen Black           Office
# 5038     Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 44180                         Recycled Paper Journal Set           Office
# 51758                            Nest Thermostat E - USA             Nest
# 5122               Nest Cam Indoor Security Camera - USA         Nest-USA
# 21586  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 28396                       Google Metallic Notebook Set           Office
# 15956              Google Laptop and Cell Phone Stickers           Office
# 14186                                Google Blackout Cap         Headgear
# 2023                    Rubber Grip Ballpoint Pen 4 Pack           Office
# 44077                                 Ballpoint Pen Blue           Office
# 30658        Nest Secure Alarm System Starter Pack - USA             Nest
# 38626             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 20504               Google Men's Vintage Badge Tee Black          Apparel
# 13854                        Google Collapsible Pet Bowl        Lifestyle
#
#        Quantity   Price  Delivery_Charges Coupon_Status   GST  Offline_Spend  \
# 31279       3.0  119.00              6.50       Clicked  0.10          700.0
# 6674        1.0   22.41              6.00       Clicked  0.18         4000.0
# 45828       1.0   19.19              6.00          Used  0.18         2500.0
# 32487       1.0   15.19              6.50       Clicked  0.18         3500.0
# 27279       2.0   79.00              6.00       Clicked  0.10         4000.0
# 42901       1.0  119.00              6.00      Not Used  0.10         1500.0
# 11104       1.0    5.10              6.00       Clicked  0.18         3000.0
# 30225       2.0   99.00              6.00          Used  0.05         2500.0
# 20143       1.0   15.19              6.00          Used  0.18         3500.0
# 27379       2.0  119.00              6.00       Clicked  0.10         3500.0
# 18743       2.0  119.00             19.99          Used  0.10         3500.0
# 12081       1.0    4.80              6.00       Clicked  0.18         1500.0
# 50939       1.0   16.79             26.43       Clicked  0.18         2500.0
# 47420      10.0    1.50              6.00       Clicked  0.18         2500.0
# 35684       1.0   67.19              6.50      Not Used  0.18         2500.0
# 1659       36.0    1.59             41.30          Used  0.10         3000.0
# 5038        1.0   80.52              6.50       Clicked  0.10         3500.0
# 44180     120.0    3.99              6.00       Clicked  0.10         2500.0
# 51758       1.0   99.00              6.00       Clicked  0.05         2000.0
# 5122        1.0  121.30              6.50          Used  0.10         4000.0
# 21586       1.0   13.59              6.00       Clicked  0.18         1500.0
# 28396      60.0    4.79             17.08       Clicked  0.10         3500.0
# 15956       1.0    1.59              6.50       Clicked  0.10         2000.0
# 14186       1.0   13.29              6.00       Clicked  0.05         3000.0
# 2023        2.0    4.12             18.47          Used  0.10         5000.0
# 44077      15.0    0.79             12.91       Clicked  0.10         2000.0
# 30658       1.0  349.00              6.00       Clicked  0.05         2000.0
# 38626       2.0  119.00              6.00       Clicked  0.10         2500.0
# 20504       3.0   10.63             46.50       Clicked  0.18         3000.0
# 13854       2.0    3.99              6.00       Clicked  0.18         3000.0
#
#        Online_Spend  Month Coupon_Code  Discount_pct
# 31279        770.87      2      ELEC20          20.0
# 6674        3434.31     12      SALE30          30.0
# 45828       1151.70      7      SALE10          10.0
# 32487       2768.28      2      SALE20          20.0
# 27279       2825.78     11      ELEC20          20.0
# 42901        985.28      7      ELEC10          10.0
# 11104       2563.83      8      SALE20          20.0
# 30225        484.90     11        NE20          20.0
# 20143       1694.16      6      SALE30          30.0
# 27379       2546.60     11      ELEC20          20.0
# 18743       1019.59      6      ELEC30          30.0
# 12081       2688.98      8      SALE20          20.0
# 50939       1783.56     10     EXTRA10          10.0
# 47420       1169.05      7     EXTRA10          10.0
# 35684       2342.68      4      SALE10          10.0
# 1659         417.73      1       OFF10          10.0
# 5038        1957.58     12      ELEC30          30.0
# 44180       2425.35      7       OFF10          10.0
# 51758       1251.87     10        NE10          10.0
# 5122        3116.98     12      ELEC30          30.0
# 21586        956.13      6      SALE30          30.0
# 28396       2087.49     11       OFF20          20.0
# 15956       1330.54      3       OFF30          30.0
# 14186       2223.08      8     HGEAR20          20.0
# 2023        2449.65      1       OFF10          10.0
# 44077       2103.13      7       OFF10          10.0
# 30658       2437.58     11        NE20          20.0
# 38626       2331.31      5      ELEC20          20.0
# 20504       2321.52      6      SALE30          30.0
# 13854       1662.28      8     EXTRA20          20.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52524 entries, 0 to 52923
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52524 non-null  float64
#  1   Gender               52524 non-null  object
#  2   Location             52524 non-null  object
#  3   Tenure_Months        52524 non-null  float64
#  4   Transaction_ID       52524 non-null  float64
#  5   Transaction_Date     52524 non-null  object
#  6   Product_SKU          52524 non-null  object
#  7   Product_Description  52524 non-null  object
#  8   Product_Category     52524 non-null  object
#  9   Quantity             52524 non-null  float64
#  10  Price                52524 non-null  float64
#  11  Delivery_Charges     52524 non-null  float64
#  12  Coupon_Status        52524 non-null  object
#  13  GST                  52524 non-null  float64
#  14  Offline_Spend        52524 non-null  float64
#  15  Online_Spend         52524 non-null  float64
#  16  Month                52524 non-null  int64
#  17  Coupon_Code          52524 non-null  object
#  18  Discount_pct         52524 non-null  float64
# dtypes: float64(10), int64(1), object(8)
# memory usage: 8.0+ MB

# %% [markdown]
# ## Remove trailing 0's

# %%
def remove_trailing_zeros_from_df(df):
    for col in df.columns:
        # Check if the column is a float dtype
        if df[col].dtype == float:
            # Use apply to convert float to int if it's an integer, else leave as float
            df[col] = df[col].apply(lambda x: int(x) if x.is_integer() else x)
    return df
df = remove_trailing_zeros_from_df(df)

# %%
df
# Out:
#        CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 0           17850      M     Chicago             12           16679
# 1           17850      M     Chicago             12           16680
# 2           17850      M     Chicago             12           16696
# 3           17850      M     Chicago             12           16699
# 4           17850      M     Chicago             12           16700
# ...           ...    ...         ...            ...             ...
# 52919       13155      F  California              8           22504
# 52920       18077      M     Chicago             34           24250
# 52921       16085      M  California             15           39991
# 52922       16085      M  California             15           39991
# 52923       13659      F     Chicago              8           39998
#
#       Transaction_Date     Product_SKU  \
# 0           2019-01-01  GGOENEBJ079499
# 1           2019-01-01  GGOENEBJ079499
# 2           2019-01-01  GGOENEBQ078999
# 3           2019-01-01  GGOENEBQ079099
# 4           2019-01-01  GGOENEBJ079499
# ...                ...             ...
# 52919       2019-03-10  GGOEGGCX056399
# 52920       2019-03-28  GGOEGGCX056299
# 52921       2019-10-06  GGOEGOCD078399
# 52922       2019-10-06  GGOEGOCR078499
# 52923       2019-10-06  GGOEGOCC077999
#
#                                      Product_Description  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2                 Nest Cam Outdoor Security Camera - USA
# 3        Nest Protect Smoke + CO White Battery Alarm-USA
# 4      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# ...                                                  ...
# 52919                                Gift Card - $250.00
# 52920                                 Gift Card - $25.00
# 52921                  Google Leather Perforated Journal
# 52922                      Google Spiral Leather Journal
# 52923                     Google Spiral Journal with Pen
#
#            Product_Category  Quantity   Price  Delivery_Charges Coupon_Status  \
# 0                  Nest-USA         1  153.71               6.5          Used
# 1                  Nest-USA         1  153.71               6.5          Used
# 2                  Nest-USA         2  122.77               6.5      Not Used
# 3                  Nest-USA         1   81.50               6.5       Clicked
# 4                  Nest-USA         1  153.71               6.5       Clicked
# ...                     ...       ...     ...               ...           ...
# 52919            Gift Cards         1  250.00               0.0       Clicked
# 52920            Gift Cards         1   25.00               0.0          Used
# 52921  Notebooks & Journals         1   10.80               6.0       Clicked
# 52922  Notebooks & Journals         1    9.60               6.0          Used
# 52923  Notebooks & Journals         1    5.59               6.5      Not Used
#
#         GST  Offline_Spend  Online_Spend  Month Coupon_Code  Discount_pct
# 0      0.10           4500       2424.50      1      ELEC10            10
# 1      0.10           4500       2424.50      1      ELEC10            10
# 2      0.10           4500       2424.50      1      ELEC10            10
# 3      0.10           4500       2424.50      1      ELEC10            10
# 4      0.10           4500       2424.50      1      ELEC10            10
# ...     ...            ...           ...    ...         ...           ...
# 52919  0.05           2500       1294.22      3        GC30            30
# 52920  0.05           2000       1066.12      3        GC30            30
# 52921  0.05           3000       2230.76     10        NJ10            10
# 52922  0.05           3000       2230.76     10        NJ10            10
# 52923  0.05           3000       2230.76     10        NJ10            10
#
# [52524 rows x 19 columns]

# %% [markdown]
# Check Missing

# %% [markdown]
# -------------------

# %%
#show all missing values
def missing_values(df):
    missing = df.isnull().sum()
    missing = missing[missing > 0]
    missing.sort_values(inplace=True)
    return missing
# print out the missing values
missing_values(df)
# Out:
# Series([], dtype: int64)

# %%
missing_values(df)
# Out:
# Series([], dtype: int64)

# %%
df.head(50)
# Out:
#     CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 0        17850      M     Chicago             12           16679
# 1        17850      M     Chicago             12           16680
# 2        17850      M     Chicago             12           16696
# 3        17850      M     Chicago             12           16699
# 4        17850      M     Chicago             12           16700
# 5        17850      M     Chicago             12           16701
# 6        17850      M     Chicago             12           16702
# 7        17850      M     Chicago             12           16703
# 8        17850      M     Chicago             12           16704
# 9        17850      M     Chicago             12           16710
# 10       17850      M     Chicago             12           16713
# 11       17850      M     Chicago             12           16719
# 12       17850      M     Chicago             12           16720
# 13       17850      M     Chicago             12           16720
# 14       17850      M     Chicago             12           16721
# 15       17850      M     Chicago             12           16722
# 16       17850      M     Chicago             12           16722
# 17       17850      M     Chicago             12           16723
# 18       17850      M     Chicago             12           16723
# 19       17850      M     Chicago             12           16724
# 20       17850      M     Chicago             12           16725
# 21       17850      M     Chicago             12           16727
# 22       17850      M     Chicago             12           16731
# 23       13047      M  California             43           16684
# 24       13047      M  California             43           16684
# 25       13047      M  California             43           16688
# 26       13047      M  California             43           16689
# 27       12583      M     Chicago             33           16694
# 28       15100      M  California             49           16712
# 29       14688      F    New York             46           16732
# 30       14688      F    New York             46           16733
# 31       14688      F    New York             46           16736
# 32       17850      M     Chicago             12           16879
# 33       17850      M     Chicago             12           16880
# 34       17850      M     Chicago             12           16881
# 35       17850      M     Chicago             12           16882
# 36       17850      M     Chicago             12           16883
# 37       17850      M     Chicago             12           16886
# 38       12431      F  New Jersey             14           16819
# 39       12431      F  New Jersey             14           16819
# 40       12431      F  New Jersey             14           16822
# 41       12431      F  New Jersey             14           16823
# 42       12431      F  New Jersey             14           16825
# 43       17511      F     Chicago             25           16826
# 44       17511      F     Chicago             25           16830
# 45       17511      F     Chicago             25           16833
# 46       17511      F     Chicago             25           16835
# 47       17511      F     Chicago             25           16836
# 48       17511      F     Chicago             25           16836
# 49       17511      F     Chicago             25           16837
#
#    Transaction_Date     Product_SKU  \
# 0        2019-01-01  GGOENEBJ079499
# 1        2019-01-01  GGOENEBJ079499
# 2        2019-01-01  GGOENEBQ078999
# 3        2019-01-01  GGOENEBQ079099
# 4        2019-01-01  GGOENEBJ079499
# 5        2019-01-01  GGOENEBJ079499
# 6        2019-01-01  GGOENEBJ079499
# 7        2019-01-01  GGOENEBQ079099
# 8        2019-01-01  GGOENEBJ079499
# 9        2019-01-01  GGOENEBJ079499
# 10       2019-01-01  GGOENEBQ078999
# 11       2019-01-01  GGOENEBJ079499
# 12       2019-01-01  GGOENEBJ079499
# 13       2019-01-01  GGOENEBQ078999
# 14       2019-01-01  GGOENEBJ079499
# 15       2019-01-01  GGOENEBJ079499
# 16       2019-01-01  GGOENEBQ078999
# 17       2019-01-01  GGOENEBB078899
# 18       2019-01-01  GGOENEBQ078999
# 19       2019-01-01  GGOENEBB078899
# 20       2019-01-01  GGOENEBB078899
# 21       2019-01-01  GGOENEBB078899
# 22       2019-01-01  GGOENEBQ078999
# 23       2019-01-01  GGOENEBQ078999
# 24       2019-01-01  GGOENEBQ079199
# 25       2019-01-01  GGOENEBB078899
# 26       2019-01-01  GGOENEBJ079499
# 27       2019-01-01  GGOENEBB078899
# 28       2019-01-01  GGOENEBJ079499
# 29       2019-01-01  GGOENEBJ079499
# 30       2019-01-01  GGOENEBB078899
# 31       2019-01-01  GGOENEBJ079499
# 32       2019-01-03  GGOENEBJ079499
# 33       2019-01-03  GGOENEBQ078999
# 34       2019-01-03  GGOENEBJ079499
# 35       2019-01-03  GGOENEBJ079499
# 36       2019-01-03  GGOENEBJ079499
# 37       2019-01-03  GGOENEBQ078999
# 38       2019-01-03  GGOENEBJ079499
# 39       2019-01-03  GGOENEBQ079199
# 40       2019-01-03  GGOENEBQ079099
# 41       2019-01-03  GGOENEBJ079499
# 42       2019-01-03  GGOENEBB078899
# 43       2019-01-03  GGOENEBJ079499
# 44       2019-01-03  GGOENEBJ079499
# 45       2019-01-03  GGOENEBJ079499
# 46       2019-01-03  GGOENEBQ078999
# 47       2019-01-03  GGOENEBJ079499
# 48       2019-01-03  GGOENEBQ079199
# 49       2019-01-03  GGOENEBQ078999
#
#                                   Product_Description Product_Category  \
# 0   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Nest Cam Outdoor Security Camera - USA         Nest-USA
# 3     Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 4   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 5   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 6   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 7     Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 8   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 9   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 10             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 11  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 12  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 13             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 14  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 15  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 16             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 17              Nest Cam Indoor Security Camera - USA         Nest-USA
# 18             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 19              Nest Cam Indoor Security Camera - USA         Nest-USA
# 20              Nest Cam Indoor Security Camera - USA         Nest-USA
# 21              Nest Cam Indoor Security Camera - USA         Nest-USA
# 22             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 23             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 24      Nest Protect Smoke + CO White Wired Alarm-USA         Nest-USA
# 25              Nest Cam Indoor Security Camera - USA         Nest-USA
# 26  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 27              Nest Cam Indoor Security Camera - USA         Nest-USA
# 28  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 29  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 30              Nest Cam Indoor Security Camera - USA         Nest-USA
# 31  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 32  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 33             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 34  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 35  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 36  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 37             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 38  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 39      Nest Protect Smoke + CO White Wired Alarm-USA         Nest-USA
# 40    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 41  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 42              Nest Cam Indoor Security Camera - USA         Nest-USA
# 43  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 44  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 45  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 46             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 47  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 48      Nest Protect Smoke + CO White Wired Alarm-USA         Nest-USA
# 49             Nest Cam Outdoor Security Camera - USA         Nest-USA
#
#     Quantity   Price  Delivery_Charges Coupon_Status  GST  Offline_Spend  \
# 0          1  153.71              6.50          Used  0.1           4500
# 1          1  153.71              6.50          Used  0.1           4500
# 2          2  122.77              6.50      Not Used  0.1           4500
# 3          1   81.50              6.50       Clicked  0.1           4500
# 4          1  153.71              6.50       Clicked  0.1           4500
# 5          1  153.71              6.50       Clicked  0.1           4500
# 6          2  153.71              6.50       Clicked  0.1           4500
# 7          2   81.50              6.50      Not Used  0.1           4500
# 8          1  256.88              6.50          Used  0.1           4500
# 9          1  153.71             28.78       Clicked  0.1           4500
# 10         1  122.77              6.50          Used  0.1           4500
# 11         1  153.71              6.50      Not Used  0.1           4500
# 12         1  153.71              6.50          Used  0.1           4500
# 13         1  122.77              6.50       Clicked  0.1           4500
# 14         1  153.71              6.50       Clicked  0.1           4500
# 15         1  153.71              6.50          Used  0.1           4500
# 16         2  122.77              6.50          Used  0.1           4500
# 17         1  122.77              6.50          Used  0.1           4500
# 18         1  122.77              6.50      Not Used  0.1           4500
# 19         1  122.77              6.50       Clicked  0.1           4500
# 20         1  122.77              6.50       Clicked  0.1           4500
# 21         1  122.77              6.50       Clicked  0.1           4500
# 22         2  122.77              6.50       Clicked  0.1           4500
# 23         2  122.77              6.50       Clicked  0.1           4500
# 24         1   81.50              6.50          Used  0.1           4500
# 25         1  122.77              6.50          Used  0.1           4500
# 26         1  153.71              6.50          Used  0.1           4500
# 27         1  122.77              6.50      Not Used  0.1           4500
# 28         1  153.71              6.50       Clicked  0.1           4500
# 29         1  153.71              6.50       Clicked  0.1           4500
# 30         1  122.77              6.50       Clicked  0.1           4500
# 31         1  153.71              6.50          Used  0.1           4500
# 32         1  153.71              6.50          Used  0.1           4500
# 33         2  122.77              6.50      Not Used  0.1           4500
# 34         1  153.71              6.50       Clicked  0.1           4500
# 35         1  153.71              6.50          Used  0.1           4500
# 36         1  153.71              6.50       Clicked  0.1           4500
# 37         1  122.77              6.50       Clicked  0.1           4500
# 38         1  153.71              6.50       Clicked  0.1           4500
# 39         1   81.50              6.50       Clicked  0.1           4500
# 40         3  102.13              6.50       Clicked  0.1           4500
# 41         4  153.71              6.50       Clicked  0.1           4500
# 42         1  122.77              6.50       Clicked  0.1           4500
# 43         1  153.71              6.50          Used  0.1           4500
# 44         1  153.71              6.50          Used  0.1           4500
# 45         1  153.71              6.50      Not Used  0.1           4500
# 46         1  122.77              6.50       Clicked  0.1           4500
# 47         2  153.71              6.50          Used  0.1           4500
# 48         2   81.50              6.50       Clicked  0.1           4500
# 49         1  122.77              6.50          Used  0.1           4500
#
#     Online_Spend  Month Coupon_Code  Discount_pct
# 0        2424.50      1      ELEC10            10
# 1        2424.50      1      ELEC10            10
# 2        2424.50      1      ELEC10            10
# 3        2424.50      1      ELEC10            10
# 4        2424.50      1      ELEC10            10
# 5        2424.50      1      ELEC10            10
# 6        2424.50      1      ELEC10            10
# 7        2424.50      1      ELEC10            10
# 8        2424.50      1      ELEC10            10
# 9        2424.50      1      ELEC10            10
# 10       2424.50      1      ELEC10            10
# 11       2424.50      1      ELEC10            10
# 12       2424.50      1      ELEC10            10
# 13       2424.50      1      ELEC10            10
# 14       2424.50      1      ELEC10            10
# 15       2424.50      1      ELEC10            10
# 16       2424.50      1      ELEC10            10
# 17       2424.50      1      ELEC10            10
# 18       2424.50      1      ELEC10            10
# 19       2424.50      1      ELEC10            10
# 20       2424.50      1      ELEC10            10
# 21       2424.50      1      ELEC10            10
# 22       2424.50      1      ELEC10            10
# 23       2424.50      1      ELEC10            10
# 24       2424.50      1      ELEC10            10
# 25       2424.50      1      ELEC10            10
# 26       2424.50      1      ELEC10            10
# 27       2424.50      1      ELEC10            10
# 28       2424.50      1      ELEC10            10
# 29       2424.50      1      ELEC10            10
# 30       2424.50      1      ELEC10            10
# 31       2424.50      1      ELEC10            10
# 32       1576.38      1      ELEC10            10
# 33       1576.38      1      ELEC10            10
# 34       1576.38      1      ELEC10            10
# 35       1576.38      1      ELEC10            10
# 36       1576.38      1      ELEC10            10
# 37       1576.38      1      ELEC10            10
# 38       1576.38      1      ELEC10            10
# 39       1576.38      1      ELEC10            10
# 40       1576.38      1      ELEC10            10
# 41       1576.38      1      ELEC10            10
# 42       1576.38      1      ELEC10            10
# 43       1576.38      1      ELEC10            10
# 44       1576.38      1      ELEC10            10
# 45       1576.38      1      ELEC10            10
# 46       1576.38      1      ELEC10            10
# 47       1576.38      1      ELEC10            10
# 48       1576.38      1      ELEC10            10
# 49       1576.38      1      ELEC10            10

# %% [markdown]
# # Feature Engineering

# %%
def update_online_spend_with_quantity(df):
    # Create a copy to sort without changing the original DataFrame's order
    df_sorted = df.sort_values(by=['CustomerID', 'Transaction_Date', 'Transaction_ID']).copy()
    
    # Initialize a dictionary to keep track of the last Online_Spend for each customer
    last_online_spend = {}
    
    # Calculate the new Online_Spend values and store them in a list
    new_online_spends = []
    
    for index, row in df_sorted.iterrows():
        customer_id = row['CustomerID']
        # Calculate the spend for this transaction, taking Quantity into account
        transaction_spend = row['Price'] * row['Quantity']
        
        if customer_id in last_online_spend:
            # Update the Online_Spend for the current purchase by adding the transaction spend
            new_spend = last_online_spend[customer_id] + transaction_spend
        else:
            # If it's the first purchase, initialize Online_Spend with this transaction's spend
            new_spend = transaction_spend
        
        # Update the last Online_Spend for this customer
        last_online_spend[customer_id] = new_spend
        # Append the updated Online_Spend value to the list
        new_online_spends.append(new_spend)
    
    # Map the new Online_Spend values back to the original DataFrame using the index from the sorted copy
    for original_idx, sorted_idx in enumerate(df_sorted.index):
        df.at[sorted_idx, 'Online_Spend'] = new_online_spends[original_idx]
    
    return df
df = update_online_spend_with_quantity(df)

# %%
df
# Out:
#        CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 0           17850      M     Chicago             12           16679
# 1           17850      M     Chicago             12           16680
# 2           17850      M     Chicago             12           16696
# 3           17850      M     Chicago             12           16699
# 4           17850      M     Chicago             12           16700
# ...           ...    ...         ...            ...             ...
# 52919       13155      F  California              8           22504
# 52920       18077      M     Chicago             34           24250
# 52921       16085      M  California             15           39991
# 52922       16085      M  California             15           39991
# 52923       13659      F     Chicago              8           39998
#
#       Transaction_Date     Product_SKU  \
# 0           2019-01-01  GGOENEBJ079499
# 1           2019-01-01  GGOENEBJ079499
# 2           2019-01-01  GGOENEBQ078999
# 3           2019-01-01  GGOENEBQ079099
# 4           2019-01-01  GGOENEBJ079499
# ...                ...             ...
# 52919       2019-03-10  GGOEGGCX056399
# 52920       2019-03-28  GGOEGGCX056299
# 52921       2019-10-06  GGOEGOCD078399
# 52922       2019-10-06  GGOEGOCR078499
# 52923       2019-10-06  GGOEGOCC077999
#
#                                      Product_Description  \
# 0      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2                 Nest Cam Outdoor Security Camera - USA
# 3        Nest Protect Smoke + CO White Battery Alarm-USA
# 4      Nest Learning Thermostat 3rd Gen-USA - Stainle...
# ...                                                  ...
# 52919                                Gift Card - $250.00
# 52920                                 Gift Card - $25.00
# 52921                  Google Leather Perforated Journal
# 52922                      Google Spiral Leather Journal
# 52923                     Google Spiral Journal with Pen
#
#            Product_Category  Quantity   Price  Delivery_Charges Coupon_Status  \
# 0                  Nest-USA         1  153.71               6.5          Used
# 1                  Nest-USA         1  153.71               6.5          Used
# 2                  Nest-USA         2  122.77               6.5      Not Used
# 3                  Nest-USA         1   81.50               6.5       Clicked
# 4                  Nest-USA         1  153.71               6.5       Clicked
# ...                     ...       ...     ...               ...           ...
# 52919            Gift Cards         1  250.00               0.0       Clicked
# 52920            Gift Cards         1   25.00               0.0          Used
# 52921  Notebooks & Journals         1   10.80               6.0       Clicked
# 52922  Notebooks & Journals         1    9.60               6.0          Used
# 52923  Notebooks & Journals         1    5.59               6.5      Not Used
#
#         GST  Offline_Spend  Online_Spend  Month Coupon_Code  Discount_pct
# 0      0.10           4500        153.71      1      ELEC10            10
# 1      0.10           4500        307.42      1      ELEC10            10
# 2      0.10           4500        983.61      1      ELEC10            10
# 3      0.10           4500       1093.15      1      ELEC10            10
# 4      0.10           4500       1246.86      1      ELEC10            10
# ...     ...            ...           ...    ...         ...           ...
# 52919  0.05           2500       2606.90      3        GC30            30
# 52920  0.05           2000        348.75      3        GC30            30
# 52921  0.05           3000       2063.82     10        NJ10            10
# 52922  0.05           3000       2073.42     10        NJ10            10
# 52923  0.05           3000       1080.62     10        NJ10            10
#
# [52524 rows x 19 columns]

# %% [markdown]
# ### Total Spend

# %%
def total_spend(df):
    # Correct the Total Spend calculation
    df['Total Spend'] = df['Offline_Spend'] + df['Online_Spend'] + df['Delivery_Charges']
    
    return df
df = total_spend(df)

# %%
df.head(50)
# Out:
#     CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 0        17850      M     Chicago             12           16679
# 1        17850      M     Chicago             12           16680
# 2        17850      M     Chicago             12           16696
# 3        17850      M     Chicago             12           16699
# 4        17850      M     Chicago             12           16700
# 5        17850      M     Chicago             12           16701
# 6        17850      M     Chicago             12           16702
# 7        17850      M     Chicago             12           16703
# 8        17850      M     Chicago             12           16704
# 9        17850      M     Chicago             12           16710
# 10       17850      M     Chicago             12           16713
# 11       17850      M     Chicago             12           16719
# 12       17850      M     Chicago             12           16720
# 13       17850      M     Chicago             12           16720
# 14       17850      M     Chicago             12           16721
# 15       17850      M     Chicago             12           16722
# 16       17850      M     Chicago             12           16722
# 17       17850      M     Chicago             12           16723
# 18       17850      M     Chicago             12           16723
# 19       17850      M     Chicago             12           16724
# 20       17850      M     Chicago             12           16725
# 21       17850      M     Chicago             12           16727
# 22       17850      M     Chicago             12           16731
# 23       13047      M  California             43           16684
# 24       13047      M  California             43           16684
# 25       13047      M  California             43           16688
# 26       13047      M  California             43           16689
# 27       12583      M     Chicago             33           16694
# 28       15100      M  California             49           16712
# 29       14688      F    New York             46           16732
# 30       14688      F    New York             46           16733
# 31       14688      F    New York             46           16736
# 32       17850      M     Chicago             12           16879
# 33       17850      M     Chicago             12           16880
# 34       17850      M     Chicago             12           16881
# 35       17850      M     Chicago             12           16882
# 36       17850      M     Chicago             12           16883
# 37       17850      M     Chicago             12           16886
# 38       12431      F  New Jersey             14           16819
# 39       12431      F  New Jersey             14           16819
# 40       12431      F  New Jersey             14           16822
# 41       12431      F  New Jersey             14           16823
# 42       12431      F  New Jersey             14           16825
# 43       17511      F     Chicago             25           16826
# 44       17511      F     Chicago             25           16830
# 45       17511      F     Chicago             25           16833
# 46       17511      F     Chicago             25           16835
# 47       17511      F     Chicago             25           16836
# 48       17511      F     Chicago             25           16836
# 49       17511      F     Chicago             25           16837
#
#    Transaction_Date     Product_SKU  \
# 0        2019-01-01  GGOENEBJ079499
# 1        2019-01-01  GGOENEBJ079499
# 2        2019-01-01  GGOENEBQ078999
# 3        2019-01-01  GGOENEBQ079099
# 4        2019-01-01  GGOENEBJ079499
# 5        2019-01-01  GGOENEBJ079499
# 6        2019-01-01  GGOENEBJ079499
# 7        2019-01-01  GGOENEBQ079099
# 8        2019-01-01  GGOENEBJ079499
# 9        2019-01-01  GGOENEBJ079499
# 10       2019-01-01  GGOENEBQ078999
# 11       2019-01-01  GGOENEBJ079499
# 12       2019-01-01  GGOENEBJ079499
# 13       2019-01-01  GGOENEBQ078999
# 14       2019-01-01  GGOENEBJ079499
# 15       2019-01-01  GGOENEBJ079499
# 16       2019-01-01  GGOENEBQ078999
# 17       2019-01-01  GGOENEBB078899
# 18       2019-01-01  GGOENEBQ078999
# 19       2019-01-01  GGOENEBB078899
# 20       2019-01-01  GGOENEBB078899
# 21       2019-01-01  GGOENEBB078899
# 22       2019-01-01  GGOENEBQ078999
# 23       2019-01-01  GGOENEBQ078999
# 24       2019-01-01  GGOENEBQ079199
# 25       2019-01-01  GGOENEBB078899
# 26       2019-01-01  GGOENEBJ079499
# 27       2019-01-01  GGOENEBB078899
# 28       2019-01-01  GGOENEBJ079499
# 29       2019-01-01  GGOENEBJ079499
# 30       2019-01-01  GGOENEBB078899
# 31       2019-01-01  GGOENEBJ079499
# 32       2019-01-03  GGOENEBJ079499
# 33       2019-01-03  GGOENEBQ078999
# 34       2019-01-03  GGOENEBJ079499
# 35       2019-01-03  GGOENEBJ079499
# 36       2019-01-03  GGOENEBJ079499
# 37       2019-01-03  GGOENEBQ078999
# 38       2019-01-03  GGOENEBJ079499
# 39       2019-01-03  GGOENEBQ079199
# 40       2019-01-03  GGOENEBQ079099
# 41       2019-01-03  GGOENEBJ079499
# 42       2019-01-03  GGOENEBB078899
# 43       2019-01-03  GGOENEBJ079499
# 44       2019-01-03  GGOENEBJ079499
# 45       2019-01-03  GGOENEBJ079499
# 46       2019-01-03  GGOENEBQ078999
# 47       2019-01-03  GGOENEBJ079499
# 48       2019-01-03  GGOENEBQ079199
# 49       2019-01-03  GGOENEBQ078999
#
#                                   Product_Description Product_Category  \
# 0   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Nest Cam Outdoor Security Camera - USA         Nest-USA
# 3     Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 4   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 5   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 6   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 7     Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 8   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 9   Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 10             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 11  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 12  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 13             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 14  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 15  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 16             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 17              Nest Cam Indoor Security Camera - USA         Nest-USA
# 18             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 19              Nest Cam Indoor Security Camera - USA         Nest-USA
# 20              Nest Cam Indoor Security Camera - USA         Nest-USA
# 21              Nest Cam Indoor Security Camera - USA         Nest-USA
# 22             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 23             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 24      Nest Protect Smoke + CO White Wired Alarm-USA         Nest-USA
# 25              Nest Cam Indoor Security Camera - USA         Nest-USA
# 26  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 27              Nest Cam Indoor Security Camera - USA         Nest-USA
# 28  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 29  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 30              Nest Cam Indoor Security Camera - USA         Nest-USA
# 31  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 32  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 33             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 34  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 35  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 36  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 37             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 38  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 39      Nest Protect Smoke + CO White Wired Alarm-USA         Nest-USA
# 40    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 41  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 42              Nest Cam Indoor Security Camera - USA         Nest-USA
# 43  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 44  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 45  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 46             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 47  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 48      Nest Protect Smoke + CO White Wired Alarm-USA         Nest-USA
# 49             Nest Cam Outdoor Security Camera - USA         Nest-USA
#
#     Quantity   Price  Delivery_Charges Coupon_Status  GST  Offline_Spend  \
# 0          1  153.71              6.50          Used  0.1           4500
# 1          1  153.71              6.50          Used  0.1           4500
# 2          2  122.77              6.50      Not Used  0.1           4500
# 3          1   81.50              6.50       Clicked  0.1           4500
# 4          1  153.71              6.50       Clicked  0.1           4500
# 5          1  153.71              6.50       Clicked  0.1           4500
# 6          2  153.71              6.50       Clicked  0.1           4500
# 7          2   81.50              6.50      Not Used  0.1           4500
# 8          1  256.88              6.50          Used  0.1           4500
# 9          1  153.71             28.78       Clicked  0.1           4500
# 10         1  122.77              6.50          Used  0.1           4500
# 11         1  153.71              6.50      Not Used  0.1           4500
# 12         1  153.71              6.50          Used  0.1           4500
# 13         1  122.77              6.50       Clicked  0.1           4500
# 14         1  153.71              6.50       Clicked  0.1           4500
# 15         1  153.71              6.50          Used  0.1           4500
# 16         2  122.77              6.50          Used  0.1           4500
# 17         1  122.77              6.50          Used  0.1           4500
# 18         1  122.77              6.50      Not Used  0.1           4500
# 19         1  122.77              6.50       Clicked  0.1           4500
# 20         1  122.77              6.50       Clicked  0.1           4500
# 21         1  122.77              6.50       Clicked  0.1           4500
# 22         2  122.77              6.50       Clicked  0.1           4500
# 23         2  122.77              6.50       Clicked  0.1           4500
# 24         1   81.50              6.50          Used  0.1           4500
# 25         1  122.77              6.50          Used  0.1           4500
# 26         1  153.71              6.50          Used  0.1           4500
# 27         1  122.77              6.50      Not Used  0.1           4500
# 28         1  153.71              6.50       Clicked  0.1           4500
# 29         1  153.71              6.50       Clicked  0.1           4500
# 30         1  122.77              6.50       Clicked  0.1           4500
# 31         1  153.71              6.50          Used  0.1           4500
# 32         1  153.71              6.50          Used  0.1           4500
# 33         2  122.77              6.50      Not Used  0.1           4500
# 34         1  153.71              6.50       Clicked  0.1           4500
# 35         1  153.71              6.50          Used  0.1           4500
# 36         1  153.71              6.50       Clicked  0.1           4500
# 37         1  122.77              6.50       Clicked  0.1           4500
# 38         1  153.71              6.50       Clicked  0.1           4500
# 39         1   81.50              6.50       Clicked  0.1           4500
# 40         3  102.13              6.50       Clicked  0.1           4500
# 41         4  153.71              6.50       Clicked  0.1           4500
# 42         1  122.77              6.50       Clicked  0.1           4500
# 43         1  153.71              6.50          Used  0.1           4500
# 44         1  153.71              6.50          Used  0.1           4500
# 45         1  153.71              6.50      Not Used  0.1           4500
# 46         1  122.77              6.50       Clicked  0.1           4500
# 47         2  153.71              6.50          Used  0.1           4500
# 48         2   81.50              6.50       Clicked  0.1           4500
# 49         1  122.77              6.50          Used  0.1           4500
#
#     Online_Spend  Month Coupon_Code  Discount_pct  Corrected Total Spend  \
# 0         153.71      1      ELEC10            10                4660.21
# 1         307.42      1      ELEC10            10                4813.92
# 2         983.61      1      ELEC10            10                5490.11
# 3        1093.15      1      ELEC10            10                5599.65
# 4        1246.86      1      ELEC10            10                5753.36
# 5        1400.57      1      ELEC10            10                5907.07
# 6        1707.99      1      ELEC10            10                6214.49
# 7        1870.99      1      ELEC10            10                6377.49
# 8        2127.87      1      ELEC10            10                6634.37
# 9        2829.71      1      ELEC10            10                7358.49
# 10       2952.48      1      ELEC10            10                7458.98
# 11       3237.11      1      ELEC10            10                7743.61
# 12       3390.82      1      ELEC10            10                7897.32
# 13       3513.59      1      ELEC10            10                8020.09
# 14       3667.30      1      ELEC10            10                8173.80
# 15       3821.01      1      ELEC10            10                8327.51
# 16       4066.55      1      ELEC10            10                8573.05
# 17       4189.32      1      ELEC10            10                8695.82
# 18       4312.09      1      ELEC10            10                8818.59
# 19       4434.86      1      ELEC10            10                8941.36
# 20       4557.63      1      ELEC10            10                9064.13
# 21       4680.40      1      ELEC10            10                9186.90
# 22       4925.94      1      ELEC10            10                9432.44
# 23        507.53      1      ELEC10            10                5014.03
# 24        589.03      1      ELEC10            10                5095.53
# 25        779.38      1      ELEC10            10                5285.88
# 26        933.09      1      ELEC10            10                5439.59
# 27        638.98      1      ELEC10            10                5145.48
# 28        153.71      1      ELEC10            10                4660.21
# 29        153.71      1      ELEC10            10                4660.21
# 30        276.48      1      ELEC10            10                4782.98
# 31        430.19      1      ELEC10            10                4936.69
# 32       5115.93      1      ELEC10            10                9622.43
# 33       5361.47      1      ELEC10            10                9867.97
# 34       5515.18      1      ELEC10            10               10021.68
# 35       5668.89      1      ELEC10            10               10175.39
# 36       5822.60      1      ELEC10            10               10329.10
# 37       6630.32      1      ELEC10            10               11136.82
# 38       1355.36      1      ELEC10            10                5861.86
# 39       1436.86      1      ELEC10            10                5943.36
# 40       1834.02      1      ELEC10            10                6340.52
# 41       2448.86      1      ELEC10            10                6955.36
# 42       2571.63      1      ELEC10            10                7078.13
# 43        153.71      1      ELEC10            10                4660.21
# 44        400.66      1      ELEC10            10                4907.16
# 45        616.26      1      ELEC10            10                5122.76
# 46        785.20      1      ELEC10            10                5291.70
# 47       1092.62      1      ELEC10            10                5599.12
# 48       1255.62      1      ELEC10            10                5762.12
# 49       1378.39      1      ELEC10            10                5884.89
#
#     Total Spend
# 0       4660.21
# 1       4813.92
# 2       5490.11
# 3       5599.65
# 4       5753.36
# 5       5907.07
# 6       6214.49
# 7       6377.49
# 8       6634.37
# 9       7358.49
# 10      7458.98
# 11      7743.61
# 12      7897.32
# 13      8020.09
# 14      8173.80
# 15      8327.51
# 16      8573.05
# 17      8695.82
# 18      8818.59
# 19      8941.36
# 20      9064.13
# 21      9186.90
# 22      9432.44
# 23      5014.03
# 24      5095.53
# 25      5285.88
# 26      5439.59
# 27      5145.48
# 28      4660.21
# 29      4660.21
# 30      4782.98
# 31      4936.69
# 32      9622.43
# 33      9867.97
# 34     10021.68
# 35     10175.39
# 36     10329.10
# 37     11136.82
# 38      5861.86
# 39      5943.36
# 40      6340.52
# 41      6955.36
# 42      7078.13
# 43      4660.21
# 44      4907.16
# 45      5122.76
# 46      5291.70
# 47      5599.12
# 48      5762.12
# 49      5884.89
